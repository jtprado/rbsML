# %% [markdown]
# # Here is our first Python program in Google Colabs
# What we will do is:
#
#
# *   We will learn object-oriented programming concepts
# *   We will learn lists
# *   We will learn dictionaries
#
# We can practive [with Hackerrank](https://www.hackerrank.com/)

# %%
print("Hello World")
# Out:
# Hello World

# %%
my_name = "joao prado"

# %%
for letter in my_name:
  print(letter)
# Out:
# j
# o
# a
# o
#
# p
# r
# a
# d
# o

# %%
print(my_name)
my_name[0:6]
# Out:
# joao prado
# 'joao p'

# %%
my_long_string = """asdasfasfsaf
asfasfasfas
asfasfasffasf"""

# %% [markdown]
# Can be important for query on a database

# %%
sql_query = """
select * from table
  where population > 1000000 and post_code = 3
"""

# %%
sql_query
# Out:
# '\nselect * from table\n  where population > 1000000 and post_code = 3\n'

# %%
x = [1, 2, 3]

# %%
y = x

# %%
print(y)
# Out:
# [1, 2, 3]

# %%
x.append(3)

# %%
x.append(1000)

# %%
print(x)
# Out:
# [1, 2, 3, 3, 1000]

# %%
my_dictionary = {
    "name": "joao", # key:value
    "age": 30,
    "city":"oldenburg"
}

# %%
your_dictionary = {
    "name": "fulano",
    "age": 45,
    "city": "sorocaba"
}

# %%
my_data = [my_dictionary, your_dictionary]

# %%
print(my_data)
# Out:
# [{'name': 'joao', 'age': 30, 'city': 'oldenburg'}, {'name': 'fulano', 'age': 45, 'city': 'sorocaba'}]
